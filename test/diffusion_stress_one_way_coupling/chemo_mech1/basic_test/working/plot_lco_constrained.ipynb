# %%
import pandas as pd
import os
import sys
import matplotlib
import matplotlib.pyplot as plt
import glob
from __future__ import print_function
import re
homedir = os.getcwd()

# %%
df_list = []
extension = 'csv'
csv_files = [i for i in glob.glob('*.{}'.format(extension))]

# %%
df1 = pd.read_csv("lco_circle_bc_no_coupling_out.csv",skiprows=[1])
df2 = pd.read_csv("lco_circle_bc_no_coupling_symmetric_out.csv",skiprows=[1])
df3 = pd.read_csv("lco_circle_bc_out.csv", skiprows=[1])
df4 = pd.read_csv("lco_circle_bc_fine_out.csv", skiprows=[1])
df5 = pd.read_csv("lco_circle_bc_symmetric_out.csv", skiprows=[1])

# %%
fig = plt.figure(figsize=(12,10))
plt.plot(df1["time"],df1["ave_conc_inner"],'k-',label=r'$no_coupling$')
plt.plot(df2["time"],df2["ave_conc_inner"],'r.',label=r'$5 \mathrm{x} 10^{-13}$')
plt.plot(df3["time"],df3["ave_conc_inner"],'b-x', label=r'$5 \mathrm{x} 10^{-14}$')
plt.plot(df4["time"],df4["ave_conc_inner"],'g-x', label=r'$5 \mathrm{x} 10^{-14}$')
plt.plot(df5["time"],df5["ave_conc_inner"],'g--o', label=r'$5 \mathrm{x} 10^{-14}$')
# plt.legend(title = r"$\rho \left(\frac{\mathrm{mol}}{\mu m^3}\right)$")
