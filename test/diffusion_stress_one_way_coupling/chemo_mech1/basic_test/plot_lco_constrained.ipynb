# %%
import pandas as pd
import os
import sys
import matplotlib
import matplotlib.pyplot as plt
homedir = os.getcwd()

# %%
df1 = pd.read_csv("lco_circle_bc_no_coupling_out.csv",skiprows=[1])
df2 = pd.read_csv("lco_circle_bc_rho_5e-13_out.csv", skiprows=[1])
df3 = pd.read_csv("lco_circle_bc_out.csv", skiprows=[1])
df4 = pd.read_csv("lco_circle_bc_symmetric_out.csv", skiprows=[1])
df5 = pd.read_csv("lco_circle_bc_symmetric_fine_out.csv", skiprows=[1])
df5.head()
# Out:
#    time  ave_conc_inner  avg_pressure
# 0   200        0.938664     -0.000211
# 1   400        0.913058     -0.000332
# 2   600        0.894133     -0.000429
# 3   800        0.877286     -0.000521
# 4  1000        0.862067     -0.000606

# %%
fig = plt.figure(figsize=(12,10))
plt.plot(df1["time"],df1["ave_conc_inner"],'k--',label=r'$1.0$')
plt.plot(df2["time"],df2["ave_conc_inner"],'r-',label=r'$5 \mathrm{x} 10^{-13}$')
plt.plot(df3["time"],df3["ave_conc_inner"],'b-x', label=r'$5 \mathrm{x} 10^{-14}$')
plt.plot(df4["time"],df4["ave_conc_inner"],'g--x', label=r'$5 \mathrm{x} 10^{-14}$')
plt.plot(df5["time"],df5["ave_conc_inner"],'g--o', label=r'$5 \mathrm{x} 10^{-14}$')
plt.legend(title = r"$\rho \left(\frac{\mathrm{mol}}{\mu m^3}\right)$")
