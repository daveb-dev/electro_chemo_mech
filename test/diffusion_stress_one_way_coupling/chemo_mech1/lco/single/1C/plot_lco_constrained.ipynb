# %%
import pandas as pd
import os
import sys
import matplotlib
import matplotlib.pyplot as plt
homedir = os.getcwd()

# %%
pressure = ['0.0','100e-6']
pressure_dir = ['pres_' + x for x in pressure]
pressure_dir
# Out:
# ['pres_0.0', 'pres_100e-6']

# %%
df_list = []

# %%
# homedir = "/home/srinath/Documents/workspace_dev/electro_chemo_mech/test/diffusion_stress_one_way_coupling/chemo_mech1/lco/single/1C"
# os.chdir(homedir)
# os.getcwd()

# %%
for i in pressure_dir:
    os.chdir(i)
    os.chdir("constrained")
    df_list.append(pd.read_csv('lco_circle_bc_out.csv',skiprows=[1,2]))
    os.chdir('../../')

# %%
for d,pr in zip(df_list, pressure):
    p = str(float(pr)*1e6) + " MPa"
    print pr, p
    plt.plot(d["time"]/7200.0, (d["axial_stress"] + float(pr))*1e12/1e5, label=p)
plt.legend()
plt.xlabel('Time/Time_period');
plt.ylabel(r'$\sigma_{11} / 10^5 $ (Pa)')
# Out:
# 0.0 0.0 MPa
# 100e-6 100.0 MPa
# Text(0,0.5,u'$\\sigma_{11} / 10^5 $ (Pa)')

# %%
for d,pr in zip(df_list, pressure):
    p = str(float(pr)*1e6) + " MPa"
    print pr, p
    plt.plot(d["ave_conc_inner"], (d["axial_stress"] + float(pr))*1e12/1e5, label=p)
plt.legend()
plt.xlabel('x (Li)')
plt.ylabel(r'$\sigma_{11} / 10^5 $ (Pa)')
plt.xlim([1.0,0.5])
# Out:
# 0.0 0.0 MPa
# 100e-6 100.0 MPa
# (1.0, 0.5)

# %%
os.getcwd()
# Out:
# '/new/home1/srinath/github/electro_chemo_mech/test/diffusion_stress_one_way_coupling/chemo_mech1/lco/single/1C'

# %%
for d,pr in zip(df_list, pressure):
    p = str(float(pr)*1e6) + " MPa"
    print pr, p
    plt.plot(d["ave_conc_inner"], (d["ave_interface_stress_rr"] + float(pr))*1e12/1e5, label=p)
plt.legend()
plt.xlabel('x (Li)')
plt.ylabel(r'$\sigma_{rr} / 10^5 $ (Pa)')
plt.xlim([1.0,0.5])
# Out:
# 0.0 0.0 MPa
# 100e-6 100.0 MPa
# (1.0, 0.5)
