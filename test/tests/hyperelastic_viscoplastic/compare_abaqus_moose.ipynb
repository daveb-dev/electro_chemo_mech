# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
os.chdir("/home/srinath/repo/github/electro_chemo_mech/test/tests/hyperelastic_viscoplastic")

# %%
df1 = pd.read_csv("Li_one_elem_out.csv")
plt.plot(df1['strain_zz'],df1['stress_zz']/1e6,'k-x')
df = pd.read_csv("stress_strain.csv")
plt.plot(df['strain_zz'], df['stress_zz']/1e6, 'r--')

# %%
df['strain_zz']
# Out:
# 0      0.000000
# 1      0.000003
# 2      0.000008
# 3      0.000014
# 4      0.000025
# 5      0.000038
# 6      0.000054
# 7      0.000070
# 8      0.000075
# 9      0.000089
# 10     0.000103
# 11     0.000121
# 12     0.000137
# 13     0.000155
# 14     0.000170
# 15     0.000184
# 16     0.000203
# 17     0.000220
# 18     0.000236
# 19     0.000241
# 20     0.000258
# 21     0.000274
# 22     0.000290
# 23     0.000309
# 24     0.000328
# 25     0.000334
# 26     0.000351
# 27     0.000368
# 28     0.000389
# 29     0.000409
#          ...
# 116    0.003223
# 117    0.003278
# 118    0.003330
# 119    0.003396
# 120    0.003459
# 121    0.003518
# 122    0.003538
# 123    0.003602
# 124    0.003662
# 125    0.003720
# 126    0.003792
# 127    0.003855
# 128    0.003877
# 129    0.003944
# 130    0.004009
# 131    0.004070
# 132    0.004148
# 133    0.004217
# 134    0.004240
# 135    0.004314
# 136    0.004385
# 137    0.004452
# 138    0.004537
# 139    0.004608
# ...

# %%
plt.plot(df2['time'],df2['amp'])

# %%
df2['amp2'] = (0.0003)*np.exp(df2['time']*0.3002)
df2['u'] = (0.0003/0.3002)*(np.exp(df2['time']*0.3002)-1)

# %%
plt.plot(df2['time'],df2['amp'],'kx')
plt.plot(df2['time'],df2['amp2'],'b')

# %%
plt.plot(df2['time'],df2['u'])

# %%
np.exp(6*0.0327)*0.0003
# Out:
# 0.000365031070514263

# %%
(0.0003/0.3002)*(np.exp(0.01*0.3002)-1)
# Out:
# 3.004507509385678e-06

# %%
5e9/2e6
# Out:
# 2500.0

# %%
2e6/5e9
# Out:
# 0.0004

# %%
np.log10(1.75)
# Out:
# 0.24303804868629442

# %%
df1
# Out:
#              time     fp_zz      peeq  peeq_rate  strain_zz      strength  \
# 0    1.000000e-08  0.000000  0.000000   0.000000   0.000000  0.000000e+00
# 1    2.000000e-08  0.000000  0.000000   0.000000   0.000000  0.000000e+00
# 2    3.000000e-08  0.000000  0.000000   0.000000   0.000000  0.000000e+00
# 3    4.000000e-08  0.000000  0.000000   0.000000   0.000000  0.000000e+00
# 4    5.500000e-08  1.002436  0.002432   0.290202   0.002997  2.057521e+06
# 5    7.000000e-08  1.002436  0.002432   0.290202   0.002997  2.057521e+06
# 6    8.500000e-08  1.002436  0.002432   0.290202   0.002997  2.057521e+06
# 7    1.000000e-07  1.002436  0.002432   0.290202   0.002997  2.057521e+06
# 8    1.225000e-07  1.006911  0.006882   0.296556   0.007481  2.160246e+06
# 9    1.450000e-07  1.006911  0.006882   0.296556   0.007481  2.160246e+06
# 10   1.675000e-07  1.006911  0.006882   0.296556   0.007481  2.160246e+06
# 11   1.900000e-07  1.006911  0.006882   0.296556   0.007481  2.160246e+06
# ...

# %%
10000/np.pi/4
# Out:
# 795.7747154594767

# %%
50*np.tan(19.7*np.pi/180)
# Out:
# 17.902591869742572
